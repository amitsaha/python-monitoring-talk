# %%
import pandas as pd
import numpy as np
metrics = pd.read_csv('./src/metrics.csv', index_col=0)
metrics[:30]
# Out:
#             request_latency
# timestamp
# 1522219451         0.111103
# 1522219451         0.056744
# 1522219451         0.052452
# 1522219451         0.051022
# 1522219451         0.053883
# 1522219451         0.057459
# 1522219451         0.052214
# 1522219451         0.050306
# 1522219451         0.053883
# 1522219451         0.058651
# 1522219451         0.058174
# 1522219451         0.051498
# 1522219451         0.051022
# 1522219451         0.051022
# 1522219451         0.051260
# 1522219451         0.050545
# 1522219451         0.051022
# 1522219451         0.050783
# 1522219451         0.050783
# 1522219451         0.044346
# 1522219451         0.043869
# 1522219451         0.044823
# 1522219451         0.139236
# 1522219451         0.044584
# 1522219451         0.043869
# 1522219451         0.043869
# 1522219451         0.043869
# 1522219451         0.039816
# 1522219451         0.039577
# 1522219451         0.039339
