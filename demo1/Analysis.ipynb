# %%
import pandas as pd
import numpy as np
metrics = pd.read_csv('/data/metrics.csv')
metrics[:30]
# Out:
#      timestamp  request_latency
# 0   1522216695         0.176907
# 1   1522216695         0.100374
# 2   1522216695         0.103712
# 3   1522216695         0.097752
# 4   1522216695         0.095129
# 5   1522216695         0.115871
# 6   1522216695         0.099897
# 7   1522216695         0.096560
# 8   1522216695         0.103712
# 9   1522216695         0.095844
# 10  1522216695         0.127554
# 11  1522216695         0.097990
# 12  1522216695         0.100136
# 13  1522216695         0.109196
# 14  1522216695         0.108004
# 15  1522216695         0.109196
# 16  1522216695         0.098705
# 17  1522216695         0.093699
# 18  1522216695         0.093699
# 19  1522216695         0.094175
# 20  1522216695         0.102043
# 21  1522216695         0.103712
# 22  1522216695         0.307083
# 23  1522216695         0.106812
# 24  1522216695         0.117540
# 25  1522216695         0.103474
# 26  1522216695         0.109196
# 27  1522216695         0.103474
# ...
